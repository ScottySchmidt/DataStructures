# %% [markdown]
# # BigO ArrayLists
# Data Structures; Illinois State University; Scott Schmidt

# %% [markdown]
# ### Determine how many times the print statement is executed in the following code fragments:
# 121  countA. Done with fragment A when n is:  10 <br>
# 33  countB. Done with fragment B when n is:  10

# %%
#fragment A:
countA=0
countB=0
n=10;
for i in range(0, n):
    for j in range(0, n):
        #print(i, " ",j)
        countA+=1
print(countA, " countA. Done with fragment A when n is: ", n)

#fragment B:
for i in range(0, n):
    for j in range(2):
        #print(i, " ",j)
        countB+=1
print(countB, " countB. Done with fragment B when n is: ", n)
# Out:
# 100  countA. Done with fragment A when n is:  10
# 20  countB. Done with fragment B when n is:  10

# %% [markdown]
# ![image.png](attachment:d3024826-eafb-4d4d-8e28-c8006bba22d8.png)

# %%
class TWArrayList:
    '''
    @param data: as list
    @param size: as int
    @param capacity: as int
    '''
    def __init__(self, data, size=0, capacity=0):
        self.data=data
        self.size=size
        self.capacity=capacity
        print(data)

    def reallocate():
        pass

    def getSize():
        return len(data)

    def getCapacity():
        return 1

    def addFirst(self, value):
        '''Adds n item to beg of arrayList'''
        self.data.append(value)
        print(self.data)

    def removeFirst(self):
        '''Remove the first item of a list'''
        if len(self.data)>0:
            self.data.pop(0)
            print(self.data)
        else:
            print("Data list has no items so cannot delete")

    def addFirstTwo(self, entry1, entry2):
        '''Add two items to list'''
        self.data.append(entry2) #second position of array
        self.data.append(entry1) #first position of array
        print(self.data)

    def indexOf(self, value): 
        '''Search for value, return first occurance in list else return -1'''
        for x in self.data:
            if x==value:
                print(self.data.index(x))
                return self.data.index(x)
        else:
            print("-1")
            return -1

# %% [markdown]
# ![image.png](attachment:e6d38bfc-177c-4ee3-be36-195d4c910ab3.png)
#
# ![image.png](attachment:22b3e70f-22a8-4ca9-8fa9-4a8b2032d914.png)![download.png](attachment:b2a7a026-5dea-4908-b631-309c6efc1cf7.png)

# %% [markdown]
# # TWArrayListTest1:
# 1. Create an array list object with constructor TWArrayList(int num) with the argument 1 (1 being the initial capacity).
# 2. Then, call addFirst(E anEntry) method three times with arguments “sun1”, “sun2” and “sun3” respectively.
# 3. Next, call addFirstTwo(E anEntry1, E anEntry2) with argument “sun4” and “sun5”.
# 4. Then, call the removeFirst() method.

# %%
tw1=TWArrayList([], 1, 1)
tw1.addFirst("sun1")
tw1.addFirst("sun2")
tw1.addFirst("sun3")
tw1.addFirstTwo("sun4", "sun5")
tw1.removeFirst()
# Out:
# []
# ['sun1']
# ['sun1', 'sun2']
# ['sun1', 'sun2', 'sun3']
# ['sun1', 'sun2', 'sun3', 'sun5', 'sun4']
# ['sun2', 'sun3', 'sun5', 'sun4']

# %% [markdown]
# # TWArrayListTest2:
# 1. Create an array list object with constructor TWArrayList().
# 2. Then, call the addFirst(E anEntry) method two times with arguments “sun1” and “sun2” respectively.
# 3. Next, call removeFirst() method three times.

# %%
tw2=TWArrayList([])
tw2.addFirst("sun1")
tw2.addFirst("sun2")
tw2.removeFirst()
tw2.removeFirst()
tw2.removeFirst() #Data list has no items so cannot delete
# Out:
# []
# ['sun1']
# ['sun1', 'sun2']
# ['sun2']
# []
# Data list has no items so cannot delete

# %% [markdown]
# # TWArrayListTest3:
# 1. Create an array list object with constructor TWArrayList().
# 2. Then call the addFirstTwo(E anEntry1, E anEntry2) method two times with arguments “sun1” and “sun2” in the first call, and “sun3” and “sun4” in the second call.
# 3. Next, call the indexOf(E value) method three times with the argument “sun1”, “sun4” and “sun5” respectively.

# %%
tw3=TWArrayList([])
tw3.addFirstTwo("sun1", "sun2")
tw3.addFirstTwo("sun3", "sun4")
tw3.indexOf("sun1")
tw3.indexOf("sun2")
tw3.indexOf("sun3")
tw3.indexOf("sun4")
tw3.indexOf("NOT_IN_LIST") # Making sure this returns -1
# Out:
# []
# ['sun2', 'sun1']
# ['sun2', 'sun1', 'sun4', 'sun3']
# 1
# 0
# 3
# 2
# -1
# -1
